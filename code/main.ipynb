# %% [markdown]
# Project explanation

# %%
# imports
import pandas as pd

cases = pd.read_csv('../data/COVID-19_aantallen_gemeente_per_dag.csv', on_bad_lines='skip', sep=";")
sewagewater = pd.read_csv('../data/COVID-19_rioolwaterdata.csv', on_bad_lines='skip', sep=";")

# %%
cases.head()
# Out:
#    Version       Date_of_report Date_of_publication Municipality_code  \
# 0        3  2022-01-26 10:00:00          2020-02-28            GM0014
# 1        3  2022-01-26 10:00:00          2020-02-28            GM0034
# 2        3  2022-01-26 10:00:00          2020-02-28            GM0037
# 3        3  2022-01-26 10:00:00          2020-02-28            GM0047
# 4        3  2022-01-26 10:00:00          2020-02-28            GM0050
#
#   Municipality_name   Province Security_region_code Security_region_name  \
# 0         Groningen  Groningen                 VR01            Groningen
# 1            Almere  Flevoland                 VR25            Flevoland
# 2       Stadskanaal  Groningen                 VR01            Groningen
# 3           Veendam  Groningen                 VR01            Groningen
# 4          Zeewolde  Flevoland                 VR25            Flevoland
#
#   Municipal_health_service                        ROAZ_region  Total_reported  \
# ...

# %%
sewagewater.head()
# Out:
#    Version Date_of_report Date_measurement  RWZI_AWZI_code RWZI_AWZI_name  \
# 0        2     2022-01-26       2020-03-30           32002        Tilburg
# 1        2     2022-01-26       2020-03-31            3010          Assen
# 2        2     2022-01-26       2020-03-31            1033    Garmerwolde
# 3        2     2022-01-26       2020-03-31            2011     Leeuwarden
# 4        2     2022-01-26       2020-03-31            1008    Stadskanaal
#
#    RNA_flow_per_100000
# 0       34621959326395
# 1       41199039310795
# 2       10473596079208
# 3       11002680177775
# 4        3802954816430
